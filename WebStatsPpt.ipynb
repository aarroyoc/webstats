# %% [markdown]
# # Web Stats ppt.adrianistan.eu

# %% [markdown]
# ## Download data

# %%
URL = "https://adrianistanlogs.blob.core.windows.net/ppt-adrianistan-eu/logs.parquet?sp=r&st=2024-10-20T15:46:17Z&se=2025-10-20T23:46:17Z&spr=https&sv=2022-11-02&sr=c&sig=%2FLzAuBx1ugfbScoGHtc3m4ddLACfkG6lRVNndPyZPog%3D"

# %%
from urllib.request import urlretrieve

urlretrieve(URL, "logs-ppt.parquet")
# Out:
# ('logs-ppt.parquet', <http.client.HTTPMessage at 0x7110b41f2180>)

# %% [markdown]
# # Analysis
#
# 1. Most popular pages
# 2. Data sent
# 3. Browsers / Operating systems
# 4. Referrals
# 5. Protocols

# %%
import duckdb
import pandas as pd

# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb
# %config SqlMagic.displaylimit = None
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %%sql
# SELECT * FROM read_parquet('logs-ppt.parquet')
# LIMIT 50
# Out:
# Running query in 'duckdb'
# +----------------+-------------+---------------------------+--------+-----------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+--------+-------------+----------+
# |  remote_addr   | remote_user |            time           | status | body_bytes_sent | http_referer |                                                                                                                                http_user_agent                                                                                                                                | http_x_forwarded_for | method |     path    | protocol |
# +----------------+-------------+---------------------------+--------+-----------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+--------+-------------+----------+
# |  66.249.73.36  |      -      | 2024-10-11 15:43:47+02:00 |  301   |       169       |      -       |                                                                                                    Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                                                   |          -           |  GET   | /robots.txt | HTTP/1.1 |
# |  66.249.73.32  |      -      | 2024-10-11 15:43:47+02:00 |  404   |       153       |      -       |                                                                                                    Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                                                   |          -           |  GET   | /robots.txt | HTTP/1.1 |
# |  66.249.73.37  |      -      | 2024-10-11 15:43:47+02:00 |  301   |       169       |      -       |                                                                                                    Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                                                   |          -           |  GET   |   /ads.txt  | HTTP/1.1 |
# |  66.249.73.39  |      -      | 2024-10-11 15:43:48+02:00 |  404   |       153       |      -       |                                                                                                    Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                                                   |          -           |  GET   |   /ads.txt  | HTTP/1.1 |
# | 198.235.24.17  |      -      | 2024-10-11 17:01:28+02:00 |  301   |       169       |      -       | Expanse, a Palo Alto Networks company, searches across the global IPv4 space multiple times per day to identify customers' presences on the Internet. If you would like to be excluded from our scans, please send IP addresses/domains to: scaninfo@paloaltonetworks.com |          -           |  GET   |      /      | HTTP/1.1 |
# |  66.249.73.37  |      -      | 2024-10-11 19:17:28+02:00 |  301   |       169       |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |      /      | HTTP/1.1 |
# |  66.249.73.33  |      -      | 2024-10-11 19:17:29+02:00 |  200   |       8200      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |      /      | HTTP/1.1 |
# |  66.249.73.33  |      -      | 2024-10-11 19:27:31+02:00 |  200   |       1017      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /25/    | HTTP/1.1 |
# |  66.249.73.33  |      -      | 2024-10-11 19:31:31+02:00 |  200   |       1221      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /23/    | HTTP/1.1 |
# |  66.249.73.33  |      -      | 2024-10-11 19:31:32+02:00 |  200   |       1000      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /22/    | HTTP/1.1 |
# |  66.249.73.33  |      -      | 2024-10-11 19:33:33+02:00 |  200   |       1000      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /24/    | HTTP/1.1 |
# |  66.249.73.32  |      -      | 2024-10-11 19:34:33+02:00 |  200   |       1045      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /26/    | HTTP/1.1 |
# |  66.249.73.39  |      -      | 2024-10-11 19:37:34+02:00 |  200   |       1171      |      -       |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /27/    | HTTP/1.1 |
# |  54.36.148.66  |      -      | 2024-10-11 21:29:22+02:00 |  404   |       153       |      -       |                                                                                                       Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)                                                                                                      |          -           |  GET   | /robots.txt | HTTP/2.0 |
# | 65.21.163.190  |      -      | 2024-10-11 22:27:36+02:00 |  404   |       153       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   | /robots.txt | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:27:36+02:00 |  200   |       8200      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |      /      | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:27:44+02:00 |  200   |       1000      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /22/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:27:50+02:00 |  200   |       1221      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /23/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:27:57+02:00 |  200   |       1000      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /24/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:04+02:00 |  200   |       1017      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /25/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:11+02:00 |  200   |       1045      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /26/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:18+02:00 |  200   |       1171      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /27/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:25+02:00 |  200   |       910       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /1/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:32+02:00 |  200   |       1056      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /10/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:38+02:00 |  200   |       1022      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /11/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:46+02:00 |  200   |       957       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /12/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:28:53+02:00 |  200   |       1173      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /13/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:01+02:00 |  200   |       970       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /14/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:08+02:00 |  200   |       720       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /15/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:14+02:00 |  200   |       1039      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /16/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:23+02:00 |  200   |       931       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /17/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:30+02:00 |  200   |       1173      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /18/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:41+02:00 |  404   |       153       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   | /robots.txt | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:41+02:00 |  200   |       1113      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /19/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:49+02:00 |  200   |       749       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /2/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:29:55+02:00 |  200   |       958       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /20/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:03+02:00 |  200   |       1127      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /21/    | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:11+02:00 |  200   |       1044      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /3/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:17+02:00 |  200   |       967       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /4/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:24+02:00 |  200   |       1005      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /5/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:32+02:00 |  200   |       837       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /6/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:40+02:00 |  200   |       1093      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /7/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:47+02:00 |  200   |       1144      |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /8/     | HTTP/1.1 |
# | 65.21.163.190  |      -      | 2024-10-11 22:30:56+02:00 |  200   |       820       |      -       |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |          -           |  GET   |     /9/     | HTTP/1.1 |
# |  54.36.148.4   |      -      | 2024-10-11 23:19:20+02:00 |  200   |       1171      |      -       |                                                                                                       Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)                                                                                                      |          -           |  GET   |     /27/    | HTTP/2.0 |
# |  66.249.73.32  |      -      | 2024-10-12 00:13:45+02:00 |  404   |       153       |      -       |                                                                                                    Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                                                   |          -           |  GET   |   /ads.txt  | HTTP/1.1 |
# | 114.119.131.28 |      -      | 2024-10-12 01:36:16+02:00 |  404   |       153       |      -       |                                                                                               Mozilla/5.0 (compatible;PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                                                                                              |          -           |  GET   | /robots.txt | HTTP/1.1 |
# | 20.171.206.94  |      -      | 2024-10-12 02:19:51+02:00 |  404   |       153       |      -       |                                                                                     Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; GPTBot/1.2; +https://openai.com/gptbot)                                                                                    |          -           |  GET   | /robots.txt | HTTP/2.0 |
# | 198.235.24.161 |      -      | 2024-10-12 02:20:31+02:00 |  200   |       8200      |      -       |                                                                                                                                       -                                                                                                                                       |          -           |  GET   |      /      | HTTP/1.1 |
# | 20.171.206.144 |      -      | 2024-10-12 02:21:32+02:00 |  301   |       169       |      -       |                                                                                     Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; GPTBot/1.0; +https://openai.com/gptbot)                                                                                    |          -           |  GET   | /robots.txt | HTTP/1.1 |
# +----------------+-------------+---------------------------+--------+-----------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+--------+-------------+----------+

# %% [markdown]
# ## Most popular pages

# %%
# %%sql
# SELECT path, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE
#     time >= DATE '2024-10-01' AND
#     time <= DATE '2024-10-31'
# GROUP BY path
# ORDER BY count DESC
# LIMIT 50
# Out:
# Running query in 'duckdb'
# +------------------------------------------------------------------+-------+
# |                               path                               | count |
# +------------------------------------------------------------------+-------+
# |                               /21/                               |  117  |
# |                               /16/                               |  115  |
# |                           /robots.txt                            |  100  |
# |                                /                                 |   69  |
# |                               /27/                               |   22  |
# |                               /22/                               |   20  |
# |                               /24/                               |   20  |
# |                               /25/                               |   19  |
# |                               /26/                               |   19  |
# |                             /ads.txt                             |   19  |
# |                               /23/                               |   19  |
# |                               /11/                               |   18  |
# |                               /12/                               |   18  |
# |                               /20/                               |   18  |
# |                               /4/                                |   18  |
# |                               /1/                                |   18  |
# |                               /8/                                |   18  |
# |                               /10/                               |   17  |
# |                               /17/                               |   17  |
# |                               /2/                                |   17  |
# |                             /main.js                             |   17  |
# |                               /14/                               |   17  |
# |                               /3/                                |   17  |
# |                               /13/                               |   17  |
# |                               /6/                                |   17  |
# |                               /18/                               |   17  |
# |                               /19/                               |   17  |
# |                               /7/                                |   17  |
# |                               /9/                                |   17  |
# |                               /5/                                |   16  |
# |                            /main.css                             |   13  |
# |                               /15/                               |   13  |
# |         /IntroduccionProgramacionLogicaScryerProlog.pdf          |   12  |
# |                           /Strand.pdf                            |   11  |
# |                    /The%20Outside%20World.pdf                    |   11  |
# |  /De%20la%20isla%20de%20Java%20a%20la%20isla%20de%20Kotlin.pdf   |   10  |
# |                         /Kandinski.pptx                          |   10  |
# |                        /OpenStreetMap.pdf                        |   10  |
# |                       /RustHourOfCode.odp                        |   10  |
# |                       /Apache%20Spark.pdf                        |   10  |
# |                      /LinuxYTapas-IPFS.odp                       |   10  |
# |                    /Corea%20del%20Norte.pptx                     |   9   |
# |     /Solving%20Puzzles%20with%20Constraint%20Programming.pdf     |   8   |
# |          /N%C3%ADquel-Cadmio_%20Mi%20bater%C3%ADa.pptx           |   8   |
# | /La%20Contaminaci%C3%B3n%20Ac%C3%BAstica%20en%20mi%20entorno.ppt |   8   |
# |                   /Training%20Web%20Design.odp                   |   7   |
# |                     /VectorizadoGenetico.odp                     |   7   |
# |                           /Prolog.pptx                           |   6   |
# |                          /wp-login.php                           |   6   |
# |                    /InstallParty%202017.pptx                     |   6   |
# +------------------------------------------------------------------+-------+

# %% [markdown]
# ## Most popular pages (filtering probably robots)

# %%
# %%sql
# SELECT path, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE
#     time >= DATE '2024-10-01' AND
#     time <= DATE '2024-10-31' AND
#     http_user_agent LIKE 'Mozilla%' AND
#     remote_addr NOT IN (
#       SELECT DISTINCT remote_addr
#       FROM read_parquet('logs-ppt.parquet')
#       WHERE path = '/robots.txt' OR path = '/rss.xml'
#     )
# GROUP BY path
# ORDER BY count DESC
# LIMIT 50
# Out:
# Running query in 'duckdb'
# +------------------------------------------------------------------+-------+
# |                               path                               | count |
# +------------------------------------------------------------------+-------+
# |                                /                                 |   35  |
# |                             /main.js                             |   12  |
# |                               /27/                               |   9   |
# |                               /12/                               |   8   |
# |                               /8/                                |   7   |
# |                      /LinuxYTapas-IPFS.odp                       |   7   |
# |                               /11/                               |   7   |
# |                            /main.css                             |   7   |
# |                               /13/                               |   7   |
# |                               /21/                               |   6   |
# |                     /VectorizadoGenetico.odp                     |   6   |
# |                               /25/                               |   6   |
# |                               /17/                               |   6   |
# |                    /The%20Outside%20World.pdf                    |   6   |
# |                               /24/                               |   6   |
# |                               /22/                               |   6   |
# |                               /6/                                |   6   |
# |                   /Training%20Web%20Design.odp                   |   6   |
# |                       /RustHourOfCode.odp                        |   6   |
# |                               /23/                               |   5   |
# |                               /9/                                |   5   |
# |                               /15/                               |   5   |
# |                               /18/                               |   5   |
# |                               /19/                               |   5   |
# |                               /7/                                |   5   |
# |                               /1/                                |   5   |
# |                       /Apache%20Spark.pdf                        |   5   |
# |       /Tecnicos%20de%20medioambiente%20en%20plasticos.pptx       |   5   |
# |                   /Presentation%20Skills.pptx                    |   5   |
# |          /Teteras%20-%20Universos%20con%20teteras.pptx           |   5   |
# |                    /Corea%20del%20Norte.pptx                     |   5   |
# |                               /2/                                |   5   |
# |                               /10/                               |   5   |
# |                           /Strand.pdf                            |   5   |
# |  /De%20la%20isla%20de%20Java%20a%20la%20isla%20de%20Kotlin.pdf   |   5   |
# |                           /Prolog.pptx                           |   5   |
# |     /Solving%20Puzzles%20with%20Constraint%20Programming.pdf     |   5   |
# |                         /Kandinski.pptx                          |   5   |
# |                               /16/                               |   5   |
# |                               /3/                                |   5   |
# |                               /14/                               |   5   |
# |                    /InstallParty%202017.pptx                     |   5   |
# |          /N%C3%ADquel-Cadmio_%20Mi%20bater%C3%ADa.pptx           |   5   |
# |                           /favicon.ico                           |   5   |
# |                               /5/                                |   5   |
# |         /IntroduccionProgramacionLogicaScryerProlog.pdf          |   5   |
# |                        /OpenStreetMap.pdf                        |   5   |
# | /La%20Contaminaci%C3%B3n%20Ac%C3%BAstica%20en%20mi%20entorno.ppt |   5   |
# |                /Rust%20en%205%20minutos.odp.pptx                 |   5   |
# |        /Elementos%20de%20un%20sistema%20de%20control.pptx        |   5   |
# +------------------------------------------------------------------+-------+

# %% [markdown]
# ## Data sent (in MB)

# %%
# %%sql
# SELECT SUM(body_bytes_sent)/1000000 FROM read_parquet('logs-ppt.parquet')
# Out:
# Running query in 'duckdb'
# +----------------------------------+
# | (sum(body_bytes_sent) / 1000000) |
# +----------------------------------+
# |            901.714478            |
# +----------------------------------+

# %%
# %%sql
# SELECT path, SUM(body_bytes_sent)/1000000 AS data_size
# FROM read_parquet('logs-ppt.parquet')
# GROUP BY path
# ORDER BY data_size DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +------------------------------------------------------------------+------------+
# |                               path                               | data_size  |
# +------------------------------------------------------------------+------------+
# |                       /RustHourOfCode.odp                        | 155.712391 |
# |                   /Presentation%20Skills.pptx                    | 139.14546  |
# |                    /InstallParty%202017.pptx                     | 117.223194 |
# |                      /LinuxYTapas-IPFS.odp                       |  86.57021  |
# |                        /OpenStreetMap.pdf                        |  78.50593  |
# |          /Teteras%20-%20Universos%20con%20teteras.pptx           | 71.639694  |
# |                           /Strand.pdf                            | 36.701511  |
# |         /IntroduccionProgramacionLogicaScryerProlog.pdf          | 27.036805  |
# |     /Solving%20Puzzles%20with%20Constraint%20Programming.pdf     | 26.352224  |
# |  /De%20la%20isla%20de%20Java%20a%20la%20isla%20de%20Kotlin.pdf   |  24.86928  |
# |                    /The%20Outside%20World.pdf                    | 23.718244  |
# |                     /VectorizadoGenetico.odp                     |  18.72961  |
# |                    /Corea%20del%20Norte.pptx                     | 14.783724  |
# |                   /Training%20Web%20Design.odp                   | 13.530778  |
# | /La%20Contaminaci%C3%B3n%20Ac%C3%BAstica%20en%20mi%20entorno.ppt | 11.225582  |
# |                       /Apache%20Spark.pdf                        |  11.21582  |
# |                         /Kandinski.pptx                          |  10.60794  |
# |                           /Prolog.pptx                           | 10.477476  |
# |        /Elementos%20de%20un%20sistema%20de%20control.pptx        |  7.320306  |
# |       /Tecnicos%20de%20medioambiente%20en%20plasticos.pptx       |  5.591388  |
# +------------------------------------------------------------------+------------+

# %% [markdown]
# ## Browsers and Operating systems

# %%
# %%sql
# SELECT http_user_agent, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# GROUP BY http_user_agent
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                                                                http_user_agent                                                                                                                                | count |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                                                                       -                                                                                                                                       |  929  |
# |                                                                                                                               Go-http-client/1.1                                                                                                                              |  330  |
# |                                                                                     Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; GPTBot/1.2; +https://openai.com/gptbot)                                                                                    |  325  |
# |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |  156  |
# |                                                                                                    Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                                                   |   46  |
# |                                                                                                       Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)                                                                                                      |   42  |
# |                                                                Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm) Chrome/116.0.1938.76 Safari/537.36                                                               |   32  |
# |                                                                                                  RepoLookoutBot/v1.1.0-310-gd6ddb61 (abuse reports to abuse@repo-lookout.org)                                                                                                 |   31  |
# |                                                                                                     Mozilla/5.0 (compatible; AwarioBot/1.0; +https://awario.com/bots.html)                                                                                                    |   30  |
# |                                                                                                    Mozilla/5.0 (compatible; SearchMySiteBot/1.0; +https://searchmysite.net)                                                                                                   |   29  |
# |                                                                              Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36                                                                              |   21  |
# |                                                                                                          WepchSearchEngine/5.0 (https://www.wepch.com/search-engine)                                                                                                          |   17  |
# |                                                                                Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko); compatible; OAI-SearchBot/1.0; +https://openai.com/searchbot                                                                               |   13  |
# |                                                                                     Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; GPTBot/1.0; +https://openai.com/gptbot)                                                                                    |   12  |
# |                                                                                            Mozilla/5.0 (compatible; DotBot/1.2; +https://opensiteexplorer.org/dotbot; help@moz.com)                                                                                           |   9   |
# |                                                                                                                             python-requests/2.31.0                                                                                                                            |   9   |
# |                                                                                                         Mozilla/5.0 (compatible; MJ12bot/v1.4.8; http://mj12bot.com/)                                                                                                         |   8   |
# |                                                                                               Mozilla/5.0 (compatible;PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                                                                                              |   7   |
# |                                                  Mozilla/5.0 (Linux; U; Android 4.4.2; en-US; HM NOTE 1W Build/KOT49H) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 UCBrowser/11.0.5.850 U3/0.8.0 Mobile Safari/534.30                                                  |   6   |
# | Expanse, a Palo Alto Networks company, searches across the global IPv4 space multiple times per day to identify customers' presences on the Internet. If you would like to be excluded from our scans, please send IP addresses/domains to: scaninfo@paloaltonetworks.com |   5   |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+

# %%
# %%sql
# SELECT 'Firefox' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Firefox%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Chrome' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Chrome%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Safari' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Safari%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Edge' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Edge%' AND http_user_agent NOT LIKE '%bot%'
# Out:
# Running query in 'duckdb'
# +---------+-------+
# | browser | count |
# +---------+-------+
# |  Safari |   58  |
# |  Chrome |   52  |
# | Firefox |   12  |
# |   Edge  |   0   |
# +---------+-------+

# %%
# %%sql
# SELECT 'Linux' AS os, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Linux%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Windows' AS os, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Windows%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'macOS' AS os, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Mac%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Android' AS os, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%Android%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'iOS' AS os, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent LIKE '%iOS%' AND http_user_agent NOT LIKE '%bot%'
# Out:
# Running query in 'duckdb'
# +---------+-------+
# |    os   | count |
# +---------+-------+
# |   iOS   |   1   |
# | Windows |   38  |
# | Android |   10  |
# |  macOS  |   12  |
# |  Linux  |   21  |
# +---------+-------+

# %%
# %%sql
# SELECT http_user_agent, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_user_agent NOT LIKE 'Mozilla%'
# GROUP BY http_user_agent
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                                                                http_user_agent                                                                                                                                | count |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                                                                       -                                                                                                                                       |  929  |
# |                                                                                                                               Go-http-client/1.1                                                                                                                              |  330  |
# |                                                                                                  RepoLookoutBot/v1.1.0-310-gd6ddb61 (abuse reports to abuse@repo-lookout.org)                                                                                                 |   31  |
# |                                                                                                          WepchSearchEngine/5.0 (https://www.wepch.com/search-engine)                                                                                                          |   17  |
# |                                                                                                                             python-requests/2.31.0                                                                                                                            |   9   |
# | Expanse, a Palo Alto Networks company, searches across the global IPv4 space multiple times per day to identify customers' presences on the Internet. If you would like to be excluded from our scans, please send IP addresses/domains to: scaninfo@paloaltonetworks.com |   5   |
# |                                                                                                           DuckDuckBot/1.0; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |   2   |
# |                                                                                                                    CCBot/2.0 (https://commoncrawl.org/faq/)                                                                                                                   |   2   |
# |                                                                                                                              Googlebot-Image/1.0                                                                                                                              |   1   |
# |                                                                                                                    Chrome Privacy Preserving Prefetch Proxy                                                                                                                   |   1   |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+

# %% [markdown]
# ## Referrals

# %%
# %%sql
# SELECT http_referer, COUNT(*) count
# FROM read_parquet('logs-ppt.parquet')
# WHERE http_referer != '-'
# GROUP BY http_referer
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-------------------------------------------------------------------------------------------------------------------+-------+
# |                                                    http_referer                                                   | count |
# +-------------------------------------------------------------------------------------------------------------------+-------+
# |                         <a href=https://ppt.adrianistan.eu>https://ppt.adrianistan.eu</a>                         |   27  |
# |               <a href=http://ppt.adrianistan.eu/robots.txt>http://ppt.adrianistan.eu/robots.txt</a>               |   6   |
# |                        <a href=https://ppt.adrianistan.eu/>https://ppt.adrianistan.eu/</a>                        |   4   |
# |             <a href=http://ppt.adrianistan.eu/security.txt>http://ppt.adrianistan.eu/security.txt</a>             |   2   |
# |                            <a href=https://www.google.com/>https://www.google.com/</a>                            |   2   |
# | <a href=http://ppt.adrianistan.eu/.well-known/security.txt>http://ppt.adrianistan.eu/.well-known/security.txt</a> |   2   |
# |                      <a href=https://ppt.adrianistan.eu/8/>https://ppt.adrianistan.eu/8/</a>                      |   2   |
# |                     <a href=https://ppt.adrianistan.eu/22/>https://ppt.adrianistan.eu/22/</a>                     |   2   |
# |                       <a href=https://blog.adrianistan.eu/>https://blog.adrianistan.eu/</a>                       |   2   |
# |                      <a href=https://ppt.adrianistan.eu/5/>https://ppt.adrianistan.eu/5/</a>                      |   2   |
# |                          <a href=http://ppt.adrianistan.eu>http://ppt.adrianistan.eu</a>                          |   1   |
# |                  <a href=http://ppt.adrianistan.eu/main.js>http://ppt.adrianistan.eu/main.js</a>                  |   1   |
# |                      <a href=http://ppt.adrianistan.eu/26/>http://ppt.adrianistan.eu/26/</a>                      |   1   |
# |                      <a href=http://ppt.adrianistan.eu/23/>http://ppt.adrianistan.eu/23/</a>                      |   1   |
# |                      <a href=http://ppt.adrianistan.eu/21/>http://ppt.adrianistan.eu/21/</a>                      |   1   |
# |                      <a href=http://ppt.adrianistan.eu/19/>http://ppt.adrianistan.eu/19/</a>                      |   1   |
# |                      <a href=http://ppt.adrianistan.eu/18/>http://ppt.adrianistan.eu/18/</a>                      |   1   |
# |                      <a href=http://ppt.adrianistan.eu/13/>http://ppt.adrianistan.eu/13/</a>                      |   1   |
# |                      <a href=http://ppt.adrianistan.eu/10/>http://ppt.adrianistan.eu/10/</a>                      |   1   |
# |                       <a href=http://ppt.adrianistan.eu/2/>http://ppt.adrianistan.eu/2/</a>                       |   1   |
# +-------------------------------------------------------------------------------------------------------------------+-------+

# %%
# %%sql
# SELECT http_referer, COUNT(*) count
# FROM read_parquet('logs-ppt.parquet')
# WHERE
#     http_referer != '-' AND
#     http_referer NOT LIKE 'https://ppt.adrianistan.eu%' AND
#     http_referer NOT LIKE 'http://ppt.adrianistan.eu%' AND
#     http_referer NOT LIKE 'http://90.170.32.205%'
# GROUP BY http_referer
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-----------------------------------------------------------------------+-------+
# |                              http_referer                             | count |
# +-----------------------------------------------------------------------+-------+
# | <a href=https://blog.adrianistan.eu/>https://blog.adrianistan.eu/</a> |   2   |
# |      <a href=https://www.google.com/>https://www.google.com/</a>      |   2   |
# |  <a href=http://blog.adrianistan.eu/>http://blog.adrianistan.eu/</a>  |   1   |
# +-----------------------------------------------------------------------+-------+

# %% [markdown]
# ## Protocols

# %%
# %%sql
# SELECT protocol, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# GROUP BY protocol
# ORDER BY count DESC
# LIMIT 5
# Out:
# Running query in 'duckdb'
# +----------+-------+
# | protocol | count |
# +----------+-------+
# | HTTP/1.1 |  1689 |
# | HTTP/2.0 |  428  |
# |   None   |   1   |
# +----------+-------+

# %%
# %%sql
# SELECT method, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# GROUP BY method
# ORDER BY count DESC
# LIMIT 10
# Out:
# Running query in 'duckdb'
# +--------+-------+
# | method | count |
# +--------+-------+
# |  GET   |  2108 |
# |  POST  |   9   |
# |  None  |   1   |
# +--------+-------+

# %% [markdown]
# ## Broken pages

# %%
# %%sql
# SELECT path, COUNT(*) AS count
# FROM read_parquet('logs-ppt.parquet')
# WHERE
#   status = 404
# GROUP BY path
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +--------------------------------------------------------------------+-------+
# |                                path                                | count |
# +--------------------------------------------------------------------+-------+
# |                            /robots.txt                             |   76  |
# |                              /ads.txt                              |   10  |
# |                            /favicon.ico                            |   6   |
# |                    /la-perlificacion-de-python                     |   4   |
# |                           /security.txt                            |   4   |
# |                     /.well-known/security.txt                      |   4   |
# |                          /tag/literatura                           |   3   |
# |                           /wp-login.php                            |   3   |
# |                          /sitemap.xml.gz                           |   2   |
# |                           /sitemaps.xml                            |   2   |
# |                            /sitemap.txt                            |   2   |
# |              /bosque-lenguaje-programacion-microsoft               |   1   |
# |                            /.git/config                            |   1   |
# |                 //wp1/wp-includes/wlwmanifest.xml                  |   1   |
# |                 //test/wp-includes/wlwmanifest.xml                 |   1   |
# |                //media/wp-includes/wlwmanifest.xml                 |   1   |
# |                 //site/wp-includes/wlwmanifest.xml                 |   1   |
# | /emulando-linus-torvalds-crea-propio-sistema-operativo-desde-0-vii |   1   |
# |                         /sitemap_index.xml                         |   1   |
# |             /mozilla-desiste-rust-sera-sustituido-jai              |   1   |
# +--------------------------------------------------------------------+-------+
