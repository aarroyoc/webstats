# %% [markdown]
# # Web Stats prologhub.com

# %% [markdown]
# ## Download data

# %%
URL = "https://adrianistanlogs.blob.core.windows.net/prologhub-com/logs.parquet?sp=r&st=2024-10-20T15:49:38Z&se=2025-10-20T23:49:38Z&spr=https&sv=2022-11-02&sr=c&sig=KPosXJYfLwln%2FCt0BaIJshbbURRS90QxlJp%2Bpq%2Bj0fo%3D"

# %%
from urllib.request import urlretrieve

urlretrieve(URL, "logs-prologhub.parquet")
# Out:
# ('logs-prologhub.parquet', <http.client.HTTPMessage at 0x7def3831c3e0>)

# %% [markdown]
# # Analysis
#
# 1. Most popular pages
# 2. Data sent
# 3. Browsers / Operating systems
# 4. Referrals
# 5. Protocols

# %%
import duckdb
import pandas as pd

# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb
# %config SqlMagic.displaylimit = None
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %%sql
# SELECT * FROM read_parquet('logs-prologhub.parquet')
# LIMIT 50
# Out:
# Running query in 'duckdb'
# +-----------------+-------------+---------------------------+--------+-----------------+-----------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+--------+----------------------------+----------+
# |   remote_addr   | remote_user |            time           | status | body_bytes_sent |                                                   http_referer                                                  |                                                                                                                                http_user_agent                                                                                                                                | http_x_forwarded_for | method |            path            | protocol |
# +-----------------+-------------+---------------------------+--------+-----------------+-----------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+--------+----------------------------+----------+
# |   121.6.209.22  |      -      | 2024-10-11 14:08:46+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/2.0 |
# |  114.119.148.94 |      -      | 2024-10-11 14:11:41+02:00 |  200   |       6673      | <a href=https://prologhub.com/?category=Web%20Development>https://prologhub.com/?category=Web%20Development</a> |                                                     Mozilla/5.0 (Linux; Android 7.0;) AppleWebKit/537.36 (KHTML, like Gecko) Mobile Safari/537.36 (compatible; PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                                                     |          -           |  GET   |       /?tag=Modules        | HTTP/1.1 |
# |  112.86.225.145 |      -      | 2024-10-11 14:13:47+02:00 |  200   |       6673      |                                                        -                                                        |                                                                                                    Sogou web spider/4.0(+http://www.sogou.com/docs/help/webmasters.htm#07)                                                                                                    |          -           |  GET   |             /              | HTTP/1.1 |
# |   121.6.209.22  |      -      | 2024-10-11 14:24:07+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/2.0 |
# |  86.245.69.118  |      -      | 2024-10-11 14:25:51+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/2.0 |
# |   65.19.138.34  |      -      | 2024-10-11 14:35:46+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                                              Feedly/1.0 (poller)                                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/1.1 |
# |   121.6.209.22  |      -      | 2024-10-11 14:39:39+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/2.0 |
# |  66.249.72.135  |      -      | 2024-10-11 15:00:45+02:00 |  301   |       169       |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |    /consuming-json-api     | HTTP/1.1 |
# |  66.249.72.136  |      -      | 2024-10-11 15:00:46+02:00 |  200   |       4908      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |    /consuming-json-api/    | HTTP/1.1 |
# |  86.245.69.118  |      -      | 2024-10-11 15:35:54+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/2.0 |
# |  198.235.24.37  |      -      | 2024-10-11 15:45:06+02:00 |  200   |       6673      |                                                        -                                                        | Expanse, a Palo Alto Networks company, searches across the global IPv4 space multiple times per day to identify customers' presences on the Internet. If you would like to be excluded from our scans, please send IP addresses/domains to: scaninfo@paloaltonetworks.com |          -           |  GET   |             /              | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 16:15:26+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |         /?tag=HTML         | HTTP/1.1 |
# |  94.152.186.69  |      -      | 2024-10-11 16:25:41+02:00 |  200   |       6673      |                                                        -                                                        |                                                                                                 Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:128.0) Gecko/20100101 Firefox/128.0                                                                                                |          -           |  GET   |             /              | HTTP/1.1 |
# |  94.152.186.69  |      -      | 2024-10-11 16:25:46+02:00 |  200   |       6673      |                                                        -                                                        |                                                                                                 Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:128.0) Gecko/20100101 Firefox/128.0                                                                                                |          -           |  GET   |             /              | HTTP/1.1 |
# | 114.119.153.132 |      -      | 2024-10-11 16:27:00+02:00 |  200   |       6673      | <a href=https://prologhub.com/?category=Web%20Development>https://prologhub.com/?category=Web%20Development</a> |                                                     Mozilla/5.0 (Linux; Android 7.0;) AppleWebKit/537.36 (KHTML, like Gecko) Mobile Safari/537.36 (compatible; PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                                                     |          -           |  GET   |        /?tag=bagof         | HTTP/1.1 |
# |  20.191.45.212  |      -      | 2024-10-11 16:52:44+02:00 |  301   |       169       |                             <a href=http://prologhub.com/>http://prologhub.com/</a>                             |                                                                                                           DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |          -           |  GET   |             /              | HTTP/1.1 |
# |  20.191.45.212  |      -      | 2024-10-11 16:52:44+02:00 |  200   |       6673      |                            <a href=https://prologhub.com/>https://prologhub.com/</a>                            |                                                                                                           DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |          -           |  GET   |             /              | HTTP/1.1 |
# |  20.191.45.212  |      -      | 2024-10-11 16:52:44+02:00 |  404   |       153       |                 <a href=https://prologhub.com/favicon.ico>https://prologhub.com/favicon.ico</a>                 |                                                                                                           DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |          -           |  GET   |        /favicon.ico        | HTTP/1.1 |
# |  20.191.45.212  |      -      | 2024-10-11 16:52:44+02:00 |  301   |       169       |                  <a href=http://prologhub.com/favicon.ico>http://prologhub.com/favicon.ico</a>                  |                                                                                                           DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |          -           |  GET   |        /favicon.ico        | HTTP/1.1 |
# |  20.191.45.212  |      -      | 2024-10-11 16:52:44+02:00 |  404   |       153       |                 <a href=https://prologhub.com/favicon.ico>https://prologhub.com/favicon.ico</a>                 |                                                                                                           DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |          -           |  GET   |        /favicon.ico        | HTTP/1.1 |
# |   54.36.149.25  |      -      | 2024-10-11 16:58:12+02:00 |  200   |       6673      |                                                        -                                                        |                                                                                                       Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)                                                                                                      |          -           |  GET   |             /              | HTTP/2.0 |
# |  86.245.69.118  |      -      | 2024-10-11 17:33:19+02:00 |  404   |       153       |                                                        -                                                        |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |          -           |  GET   |       /updates.atom        | HTTP/2.0 |
# |  66.249.65.103  |      -      | 2024-10-11 17:53:00+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /?tag=game%20tree      | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 17:54:00+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |       /?tag=Sessions       | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 17:58:01+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |  /?category=Introductory   | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 18:03:08+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /?tag=Constraints      | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:03:09+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=PlDoc         | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:03:09+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |       /?tag=Triples        | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:06:09+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |  /?tag=Difference%20Lists  | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 18:09:10+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=layout        | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 18:14:14+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |       /?tag=findall        | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:14:15+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=bagof         | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 18:14:15+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /?tag=development      | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:18:16+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=PLUnit        | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:18:16+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |       /?tag=append/3       | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 18:21:17+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |         /?tag=call         | HTTP/1.1 |
# | 114.119.136.128 |      -      | 2024-10-11 18:22:37+02:00 |  200   |       6673      | <a href=https://prologhub.com/?category=Web%20Development>https://prologhub.com/?category=Web%20Development</a> |                                                     Mozilla/5.0 (Linux; Android 7.0;) AppleWebKit/537.36 (KHTML, like Gecko) Mobile Safari/537.36 (compatible; PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                                                     |          -           |  GET   |     /?tag=Reification      | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:23:17+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |         /?tag=APNS         | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:24:17+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |      /?tag=Tau-Prolog      | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:26:18+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |    /?category=Security     | HTTP/1.1 |
# |  114.119.148.94 |      -      | 2024-10-11 18:27:37+02:00 |  200   |       6673      | <a href=https://prologhub.com/?category=Web%20Development>https://prologhub.com/?category=Web%20Development</a> |                                                     Mozilla/5.0 (Linux; Android 7.0;) AppleWebKit/537.36 (KHTML, like Gecko) Mobile Safari/537.36 (compatible; PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                                                     |          -           |  GET   |      /?tag=JavaScript      | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:29:20+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |         /?tag=dcg          | HTTP/1.1 |
# |  66.249.65.103  |      -      | 2024-10-11 18:30:20+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |     /?tag=Reification      | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:34:20+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=future        | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:35:21+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |      /?author=pmoura       | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:38:21+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |       /?tag=oncology       | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:39:21+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=HTTP/2        | HTTP/1.1 |
# |  66.249.65.102  |      -      | 2024-10-11 18:40:22+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |        /?tag=setof         | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:42:22+02:00 |  200   |       6673      |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   | /?tag=Negation,%20Ontology | HTTP/1.1 |
# |  66.249.65.104  |      -      | 2024-10-11 18:42:22+02:00 |  301   |       169       |                                                        -                                                        |                                    Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                    |          -           |  GET   |       /tag/relations       | HTTP/1.1 |
# +-----------------+-------------+---------------------------+--------+-----------------+-----------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+--------+----------------------------+----------+

# %% [markdown]
# ## Most popular pages

# %%
# %%sql
# SELECT path, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE
#     time >= DATE '2024-10-01' AND
#     time <= DATE '2024-10-31'
# GROUP BY path
# ORDER BY count DESC
# LIMIT 50
# Out:
# Running query in 'duckdb'
# +---------------------------------------------------------------------------+-------+
# |                                    path                                   | count |
# +---------------------------------------------------------------------------+-------+
# |                               /updates.atom                               |  261  |
# |                                /robots.txt                                |  249  |
# |                                     /                                     |  248  |
# |                         /using-postgresql-prolog/                         |  128  |
# |                                 /archive/                                 |  118  |
# |                          /using-postgresql-prolog                         |  110  |
# |                     /scryer-prolog-meetup-2023-notes/                     |  110  |
# |                      /scryer-prolog-meetup-2023-notes                     |  108  |
# |                                /favicon.ico                               |   64  |
# |                             /static/fonts.css                             |   39  |
# |                              /static/main.css                             |   39  |
# |                          /static/B612-Regular.ttf                         |   35  |
# |                               /wp-login.php                               |   34  |
# |                    /homoiconic-prolog-explain-yourself/                   |   21  |
# |                    /parallel-logic-programming-sequel/                    |   21  |
# |                              /framing-frames/                             |   19  |
# |                                /xmlrpc.php                                |   18  |
# |                                    /bk                                    |   16  |
# |                                   /home                                   |   16  |
# |                                    /wp                                    |   16  |
# |                                    /old                                   |   16  |
# |                                    /new                                   |   16  |
# |                                 /wordpress                                |   16  |
# |                                    /bc                                    |   16  |
# |                                   /main                                   |   16  |
# |                        /awkward-id-generation-dcg/                        |   16  |
# |                                  /backup                                  |   16  |
# | /using-prolog-unravel-foundations-oncology-dose-escalation-trial-designs/ |   14  |
# |                     /is_of-and-has_-predicate-naming/                     |   14  |
# |                  /libraryffi-now-available-scryer-prolog/                 |   14  |
# |                  /operators-controlled-natural-language/                  |   13  |
# |                                 /tag/cnl/                                 |   13  |
# |         /tips-planning-documenting-and-testing-swi-prolog-project/        |   13  |
# |                                  /rss.xml                                 |   12  |
# |  /using-prolog-unravel-foundations-oncology-dose-escalation-trial-designs |   12  |
# |                               /?tag=Sessions                              |   11  |
# |                     /parallel-logic-programming-sequel                    |   11  |
# |                                /tag/roles/                                |   11  |
# |                                /?tag=Roles                                |   11  |
# |                  /libraryffi-now-available-scryer-prolog                  |   10  |
# |                                /?tag=HTTP/2                               |   10  |
# |                     /graph-traversal-problem-solving/                     |   10  |
# |                                 /?tag=APNS                                |   10  |
# |                                /?tag=dif/2                                |   10  |
# |                                  /tag/cnl                                 |   10  |
# |                               /?tag=Logtalk                               |   9   |
# |                 /opening-prolog-world-three-valued-logic/                 |   9   |
# |                              /?tag=Tau-Prolog                             |   9   |
# |                                 /?tag=Dict                                |   9   |
# |                     /transitive-relations-deeper-dive/                    |   9   |
# +---------------------------------------------------------------------------+-------+

# %% [markdown]
# ## Most popular pages (filtering probably robots)

# %%
# %%sql
# SELECT path, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE
#     time >= DATE '2024-10-01' AND
#     time <= DATE '2024-10-31' AND
#     http_user_agent LIKE 'Mozilla%' AND
#     remote_addr NOT IN (
#       SELECT DISTINCT remote_addr
#       FROM read_parquet('logs-prologhub.parquet')
#       WHERE path = '/robots.txt' OR path = '/rss.xml'
#     )
# GROUP BY path
# ORDER BY count DESC
# LIMIT 50
# Out:
# Running query in 'duckdb'
# +---------------------------------------------------------------------------+-------+
# |                                    path                                   | count |
# +---------------------------------------------------------------------------+-------+
# |                                     /                                     |  126  |
# |                          /static/B612-Regular.ttf                         |   35  |
# |                             /static/fonts.css                             |   34  |
# |                              /static/main.css                             |   34  |
# |                               /wp-login.php                               |   34  |
# |                                /favicon.ico                               |   28  |
# |                               /updates.atom                               |   22  |
# |                         /using-postgresql-prolog/                         |   19  |
# |                                /xmlrpc.php                                |   18  |
# |                                    /wp                                    |   16  |
# |                                    /old                                   |   16  |
# |                                    /new                                   |   16  |
# |                                  /backup                                  |   16  |
# |                                    /bk                                    |   16  |
# |                                   /home                                   |   16  |
# |                                 /wordpress                                |   16  |
# |                                    /bc                                    |   16  |
# |                                   /main                                   |   16  |
# |                    /homoiconic-prolog-explain-yourself/                   |   13  |
# |                              /framing-frames/                             |   11  |
# |                                /tag/roles/                                |   9   |
# |                    /parallel-logic-programming-sequel/                    |   9   |
# |         /tips-planning-documenting-and-testing-swi-prolog-project/        |   8   |
# |                        /awkward-id-generation-dcg/                        |   8   |
# |                  /operators-controlled-natural-language/                  |   7   |
# |                                   /.env                                   |   7   |
# |                                 /tag/dcg/                                 |   6   |
# |                                 /tag/cnl/                                 |   6   |
# |                  /libraryffi-now-available-scryer-prolog/                 |   6   |
# |                         /?tag=setup_call_cleanup/3                        |   6   |
# | /using-prolog-unravel-foundations-oncology-dose-escalation-trial-designs/ |   6   |
# |                              /?tag=Tau-Prolog                             |   5   |
# |                                /?tag=HTTP/2                               |   5   |
# |                                /?tag=setof                                |   5   |
# |           /reflexive-symmetric-and-transitive-relations-prolog/           |   5   |
# |                   /media/images/terminal2.width-500.png                   |   5   |
# |                     /is_of-and-has_-predicate-naming/                     |   5   |
# |                              /tag/relations/                              |   5   |
# |                            /consuming-json-api/                           |   5   |
# |                         /?tag=Negation,%20Ontology                        |   5   |
# |                               /tag/relations                              |   5   |
# |                             /documents/1/kb.pl                            |   5   |
# |                    /hello-name-second-program-improved/                   |   5   |
# |                             /hello-tau-prolog/                            |   5   |
# |          /dcgs-provide-threading-state-abstraction-dont-break-it/         |   5   |
# |  /using-prolog-unravel-foundations-oncology-dose-escalation-trial-designs |   5   |
# |                          /?category=Introductory                          |   4   |
# |                                /tag/frames/                               |   4   |
# |                            /static/browser1.png                           |   4   |
# |                       /static/snoopy_composition.jpg                      |   4   |
# +---------------------------------------------------------------------------+-------+

# %% [markdown]
# ## Data sent (in MB)

# %%
# %%sql
# SELECT SUM(body_bytes_sent)/1000000 FROM read_parquet('logs-prologhub.parquet')
# Out:
# Running query in 'duckdb'
# +----------------------------------+
# | (sum(body_bytes_sent) / 1000000) |
# +----------------------------------+
# |            16.904777             |
# +----------------------------------+

# %%
# %%sql
# SELECT path, SUM(body_bytes_sent)/1000000 AS data_size
# FROM read_parquet('logs-prologhub.parquet')
# GROUP BY path
# ORDER BY data_size DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +------------------------------------------------------------+-----------+
# |                            path                            | data_size |
# +------------------------------------------------------------+-----------+
# |                  /static/B612-Regular.ttf                  |  4.478346 |
# |                             /                              |  1.073344 |
# |                         /archive/                          |  0.837092 |
# |                 /using-postgresql-prolog/                  |  0.777757 |
# |                    /static/browser2.png                    |  0.417776 |
# |                   /static/terminal3.png                    |  0.281652 |
# |   /static/Snoopys-Dark-and-Stormy-Night-Second-Line.jpg    |  0.278612 |
# |                    /static/browser1.png                    |  0.26756  |
# | /tips-planning-documenting-and-testing-swi-prolog-project/ |  0.245232 |
# |                   /static/terminal1.png                    |  0.218932 |
# |                   /static/terminal4.png                    |  0.202336 |
# |                   /static/terminal2.png                    |  0.196112 |
# |             /scryer-prolog-meetup-2023-notes/              |   0.1936  |
# |                      /framing-frames/                      |  0.176434 |
# |                          /rss.xml                          |  0.136728 |
# |            /homoiconic-prolog-explain-yourself/            |  0.128847 |
# |         /functional-prolog-map-filter-and-reduce/          |  0.080304 |
# |                /difference-lists-explored/                 |  0.078536 |
# |            /parallel-logic-programming-sequel/             |  0.078078 |
# |                        /?tag=Roles                         |  0.073403 |
# +------------------------------------------------------------+-----------+

# %% [markdown]
# ## Browsers and Operating systems

# %%
# %%sql
# SELECT http_user_agent, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# GROUP BY http_user_agent
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                             http_user_agent                                                                                             | count |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# | Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.89 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html) |  1057 |
# |                                                                                            Go-http-client/1.1                                                                                           |  554  |
# |                                                                    Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)                                                                   |  260  |
# |                                                                            NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                           |  209  |
# |                                                 Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; ClaudeBot/1.0; +claudebot@anthropic.com)                                                 |  187  |
# |                                                               Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot.html)                                                               |  178  |
# |                  Mozilla/5.0 (Linux; Android 7.0;) AppleWebKit/537.36 (KHTML, like Gecko) Mobile Safari/537.36 (compatible; PetalBot;+https://webmaster.petalsearch.com/site/petalbot)                  |  162  |
# |                                           Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36                                           |  160  |
# |                                                         Mozilla/5.0 (compatible; DotBot/1.2; +https://opensiteexplorer.org/dotbot; help@moz.com)                                                        |   99  |
# |                         Mozlila/5.0 (Linux; Android 7.0; SM-G892A Bulid/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/60.0.3112.107 Moblie Safari/537.36                        |   83  |
# |                                                                        DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                       |   55  |
# |                                                                 Sogou web spider/4.0(+http://www.sogou.com/docs/help/webmasters.htm#07)                                                                 |   48  |
# |                             Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm) Chrome/116.0.1938.76 Safari/537.36                            |   47  |
# |                           Mozilla/5.0 (Linux; Android 5.0) AppleWebKit/537.36 (KHTML, like Gecko) Mobile Safari/537.36 (compatible; Bytespider; spider-feedback@bytedance.com)                          |   45  |
# |                                                                  Mozilla/5.0 (compatible; Barkrowler/0.9; +https://babbar.tech/crawler)                                                                 |   44  |
# |                                                                facebookexternalhit/1.1 (+http://www.facebook.com/externalhit_uatext.php)                                                                |   42  |
# |                                                                  Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko                                                                  |   36  |
# |                                                        meta-externalagent/1.1 (+https://developers.facebook.com/docs/sharing/webmasters/crawler)                                                        |   34  |
# |                                                                 Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)                                                                |   31  |
# |                                                             Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:131.0) Gecko/20100101 Firefox/131.0                                                            |   29  |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+

# %%
# %%sql
# SELECT 'Firefox' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Firefox%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Chrome' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Chrome%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Safari' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Safari%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Edge' AS browser, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Edge%' AND http_user_agent NOT LIKE '%bot%'
# Out:
# Running query in 'duckdb'
# +---------+-------+
# | browser | count |
# +---------+-------+
# |  Chrome |  536  |
# |  Safari |  625  |
# | Firefox |  114  |
# |   Edge  |   7   |
# +---------+-------+

# %%
# %%sql
# SELECT 'Linux' AS os, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Linux%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Windows' AS os, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Windows%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'macOS' AS os, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Mac%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'Android' AS os, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%Android%' AND http_user_agent NOT LIKE '%bot%'
# UNION
# SELECT 'iOS' AS os, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent LIKE '%iOS%' AND http_user_agent NOT LIKE '%bot%'
# Out:
# Running query in 'duckdb'
# +---------+-------+
# |    os   | count |
# +---------+-------+
# | Windows |  483  |
# | Android |  211  |
# |  macOS  |   55  |
# |  Linux  |  239  |
# |   iOS   |   0   |
# +---------+-------+

# %%
# %%sql
# SELECT http_user_agent, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_user_agent NOT LIKE 'Mozilla%'
# GROUP BY http_user_agent
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                                                                http_user_agent                                                                                                                                | count |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                                                               Go-http-client/1.1                                                                                                                              |  554  |
# |                                                                                                               NetNewsWire (RSS Reader; https://netnewswire.com/)                                                                                                              |  209  |
# |                                                            Mozlila/5.0 (Linux; Android 7.0; SM-G892A Bulid/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/60.0.3112.107 Moblie Safari/537.36                                                           |   83  |
# |                                                                                                           DuckDuckBot/1.1; (+http://duckduckgo.com/duckduckbot.html)                                                                                                          |   55  |
# |                                                                                                    Sogou web spider/4.0(+http://www.sogou.com/docs/help/webmasters.htm#07)                                                                                                    |   48  |
# |                                                                                                   facebookexternalhit/1.1 (+http://www.facebook.com/externalhit_uatext.php)                                                                                                   |   42  |
# |                                                                                           meta-externalagent/1.1 (+https://developers.facebook.com/docs/sharing/webmasters/crawler)                                                                                           |   34  |
# |                                                                                                                    CCBot/2.0 (https://commoncrawl.org/faq/)                                                                                                                   |   21  |
# |                                                                                                                    Aggregator/2.22.000 (Android/9; MSM8974)                                                                                                                   |   11  |
# |                                                                                                                               Go-http-client/2.0                                                                                                                              |   9   |
# |                                                                                                                             python-requests/2.31.0                                                                                                                            |   9   |
# |                                                                                                                                       -                                                                                                                                       |   8   |
# |                                                                                                                          2ip bot/1.1 (+http://2ip.io)                                                                                                                         |   6   |
# | Expanse, a Palo Alto Networks company, searches across the global IPv4 space multiple times per day to identify customers' presences on the Internet. If you would like to be excluded from our scans, please send IP addresses/domains to: scaninfo@paloaltonetworks.com |   5   |
# |                                                                                                            rss2email/3.14 (https://github.com/rss2email/rss2email)                                                                                                            |   5   |
# |                                                                                                                             python-requests/2.32.3                                                                                                                            |   2   |
# |                                                                                                                    Chrome Privacy Preserving Prefetch Proxy                                                                                                                   |   2   |
# |                                                                                                                                    Feedbin                                                                                                                                    |   2   |
# |                                                                                                                              Feedly/1.0 (poller)                                                                                                                              |   2   |
# |                                                                                                                                   Feedly/1.0                                                                                                                                  |   2   |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+

# %% [markdown]
# ## Referrals

# %%
# %%sql
# SELECT http_referer, COUNT(*) count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE http_referer != '-'
# GROUP BY http_referer
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                                                 http_referer                                                                                | count |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                               <a href=https://prologhub.com/?category=Web%20Development>https://prologhub.com/?category=Web%20Development</a>                               |  122  |
# |                           <a href=https://prologhub.com/scryer-prolog-meetup-2023-notes>https://prologhub.com/scryer-prolog-meetup-2023-notes</a>                           |  106  |
# |                                   <a href=https://prologhub.com/using-postgresql-prolog>https://prologhub.com/using-postgresql-prolog</a>                                   |  105  |
# |                                                          <a href=https://prologhub.com/>https://prologhub.com/</a>                                                          |   53  |
# | <a href=https://prologhub.com/tips-planning-documenting-and-testing-swi-prolog-project/>https://prologhub.com/tips-planning-documenting-and-testing-swi-prolog-project/</a> |   40  |
# |                                          <a href=https://prologhub.com/static/fonts.css>https://prologhub.com/static/fonts.css</a>                                          |   33  |
# |                                                           <a href=http://prologhub.com/>http://prologhub.com/</a>                                                           |   26  |
# |                                               <a href=https://prologhub.com/favicon.ico>https://prologhub.com/favicon.ico</a>                                               |   22  |
# |                                                            <a href=http://prologhub.com>http://prologhub.com</a>                                                            |   20  |
# |                                                         <a href=https://www.google.com/>https://www.google.com/</a>                                                         |   12  |
# |                        <a href=https://prologhub.com/parallel-logic-programming-sequel/>https://prologhub.com/parallel-logic-programming-sequel/</a>                        |   12  |
# |                                           <a href=https://prologhub.com/framing-frames/>https://prologhub.com/framing-frames/</a>                                           |   12  |
# |                                                <a href=http://prologhub.com/favicon.ico>http://prologhub.com/favicon.ico</a>                                                |   11  |
# |                                  <a href=https://prologhub.com/using-postgresql-prolog/>https://prologhub.com/using-postgresql-prolog/</a>                                  |   11  |
# |                                                   <a href=https://prologhub.com/?page=5>https://prologhub.com/?page=5</a>                                                   |   9   |
# |                                                         <a href=http://prologhub.com/wp>http://prologhub.com/wp</a>                                                         |   8   |
# |                                                        <a href=http://prologhub.com/old>http://prologhub.com/old</a>                                                        |   8   |
# |                                                       <a href=http://prologhub.com/home>http://prologhub.com/home</a>                                                       |   8   |
# |                                                         <a href=http://prologhub.com/bk>http://prologhub.com/bk</a>                                                         |   8   |
# |                                                       <a href=http://prologhub.com/main>http://prologhub.com/main</a>                                                       |   8   |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+

# %%
# %%sql
# SELECT http_referer, COUNT(*) count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE
#     http_referer != '-' AND
#     http_referer NOT LIKE 'https://prologhub.com%' AND
#     http_referer NOT LIKE 'http://prologhub.com%' AND
#     http_referer NOT LIKE 'http://90.170.32.205%'
# GROUP BY http_referer
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +---------------------------------------------------------------------+-------+
# |                             http_referer                            | count |
# +---------------------------------------------------------------------+-------+
# |     <a href=https://www.google.com/>https://www.google.com/</a>     |   12  |
# | <a href=https://1pluslocksmith.com/>https://1pluslocksmith.com/</a> |   5   |
# |          <a href=https://yandex.ru/>https://yandex.ru/</a>          |   5   |
# |         <a href=https://google.com/>https://google.com/</a>         |   4   |
# | <a href=https://learn-anything.xyz/>https://learn-anything.xyz/</a> |   2   |
# |    <a href=http://www.feiacmr.shop/>http://www.feiacmr.shop/</a>    |   2   |
# |     <a href=https://duckduckgo.com/>https://duckduckgo.com/</a>     |   2   |
# |   <a href=https://web.telegram.org/>https://web.telegram.org/</a>   |   1   |
# |       <a href=https://www.bing.com/>https://www.bing.com/</a>       |   1   |
# +---------------------------------------------------------------------+-------+

# %% [markdown]
# ## Protocols

# %%
# %%sql
# SELECT protocol, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# GROUP BY protocol
# ORDER BY count DESC
# LIMIT 5
# Out:
# Running query in 'duckdb'
# +----------+-------+
# | protocol | count |
# +----------+-------+
# | HTTP/1.1 |  2941 |
# | HTTP/2.0 |  1068 |
# | HTTP/1.0 |   5   |
# |   None   |   1   |
# +----------+-------+

# %%
# %%sql
# SELECT method, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# GROUP BY method
# ORDER BY count DESC
# LIMIT 10
# Out:
# Running query in 'duckdb'
# +--------+-------+
# | method | count |
# +--------+-------+
# |  GET   |  3838 |
# |  HEAD  |  160  |
# |  POST  |   16  |
# |  None  |   1   |
# +--------+-------+

# %% [markdown]
# ## Broken pages

# %%
# %%sql
# SELECT path, COUNT(*) AS count
# FROM read_parquet('logs-prologhub.parquet')
# WHERE
#   status = 404
# GROUP BY path
# ORDER BY count DESC
# LIMIT 20
# Out:
# Running query in 'duckdb'
# +-----------------------------------------------+-------+
# |                      path                     | count |
# +-----------------------------------------------+-------+
# |                 /updates.atom                 |  257  |
# |                  /robots.txt                  |  208  |
# |                  /favicon.ico                 |   53  |
# |                 /wp-login.php                 |   22  |
# |                  /xmlrpc.php                  |   12  |
# |                    /backup                    |   8   |
# |                      /wp                      |   8   |
# |                      /old                     |   8   |
# |                      /new                     |   8   |
# |                      /bk                      |   8   |
# |                     /home                     |   8   |
# |                   /wordpress                  |   8   |
# |                      /bc                      |   8   |
# |                     /main                     |   8   |
# |       /documents/2/inference_4x3K0hZ.pl       |   6   |
# |        /wp-includes/images/include.php        |   6   |
# |               /documents/1/kb.pl              |   6   |
# | /wp-content/plugins/WordPressCore/include.php |   6   |
# |         /wp-content/themes/include.php        |   6   |
# |        /wp-includes/widgets/include.php       |   5   |
# +-----------------------------------------------+-------+
